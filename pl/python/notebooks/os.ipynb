# %% [markdown]
# # os
#
# To module os

# %% [markdown]
#     Τμήμα Πληροφορικής και Τηλεπικοινωνιών - Άρτα
#     Πανεπιστήμιο Ιωαννίνων
#
#     Γκόγκος Χρήστος
#     http://chgogos.github.io/
#     Τελευταία ενημέρωση: 15/3/2022

# %% [markdown]
# To module os επιτρέπει τη χρήση λειτουργικότητας του Λειτουργικού Συστήματος. Επιτρέπει την πλοήγηση στο σύστημα αρχείων, τη λήψη πληροφοριών σχετικά με τα αρχεία και τους καταλόγους, τη μετονομάσια αρχείων, τη λήψη μεταβλητών συστήματος κ.α.

# %%
import os # builtin module

# %%
# τρέχον κατάλογος
cwd = os.getcwd()
print(cwd)
# Out:
# e:\git_repos\dituoi_agp\pl\python\notebooks

# %%
# πλοήγηση σε καταλόγους και εμφάνιση λίστας αρχείων 
os.chdir("../../../datasets") # αλλαγή τρέχοντος καταλόγου
print(os.listdir(".")) # επιστροφή λίστας με τα αρχεία ενός καταλόγου
os.chdir(cwd) # επιστροφή στον αρχικό κατάλογο
# Out:
# ['advent2020_18.txt', 'cal_housing.csv', 'cal_housing.xls', 'cal_housing.xlsx', 'dit.json', 'dummy.txt', 'google_stock_data.csv', 'google_stock_data_output.csv', 'greek_cities.csv', 'index.md', 'iris.csv', 'itc2021', 'metamorphosis.txt', 'ml-100k', 'movies.json', 'movies.xml', 'notes.xml', 'person.json', 'person.xml', 'person.yaml', 'tasks_example.ini', 'text_for_regex_experiments.txt']

# %%
# δημιουργία νέου καταλόγου και διαγραφή καταλόγου
os.mkdir('temp')
print(os.listdir("."))
os.rmdir('temp')
# Out:
# ['.ipynb_checkpoints', '01-intro.ipynb', '02-strings.ipynb', '03-lists-tuples-dictionaries-sets.ipynb', '04-conditionals.ipynb', '05-loops.ipynb', '06-comprehensions.ipynb', '07-exceptions.ipynb', '08-files.ipynb', '09-functions.ipynb', '10-lambdas.ipynb', '11-classes.ipynb', '12-logging.ipynb', '13-testing.ipynb', '14-csv.ipynb', '15-excel.ipynb', '16-xml.ipynb', '17-json.ipynb', '18-yaml.ipynb', '19-pickle.ipynb', '20-datetime.ipynb', '21-random.ipynb', '22-regular_expressions.ipynb', '23-generators.ipynb', '24-iterators.ipynb', '25-itertools.ipynb', '26-enums.ipynb', '27-urllib.ipynb', '28-requests.ipynb', '29-bs4.ipynb', '30-collections.ipynb', '31-PLY.ipynb', '32-alias.ipynb', '33-abstract_syntax_trees.ipynb', '34-operator_overloading.ipynb', 'APIs.ipynb', 'attrs.ipynb', 'birthday_paradox.pkl', 'code_analysis.ipynb', 'configparser.ipynb', 'convert.bat', 'coroutines.ipynb', 'data.pkl', 'decorators.ipynb', 'dituoi.pkl', 'easter_eggs.ipynb', 'functools.ipynb', 'LEGB.ipynb', 'mocking.ipynb', 'numpy.ipynb', 'os.ipynb', 'pandas.ipynb', 'parser.out', 'parsetab.py', 'partial_function_example1.py', 'partial_function_example2.py', 'print_debugging.ipynb', 'profiling.ipynb', 'pylint.ipynb', 'sample.log', 'seaborn.ipynb', 'sols.ipynb', 'sols7_1.ipynb', 'sols7_2a.ipynb', 'sols7_2a_alt.ipynb', 'sols7_2b.ipynb', 'sols7_2b_alt.ipynb', 'sqlite.ipynb', 'temp', 'temp.ipynb', 'test.txt', 'threads.ipynb', 'wiki.jpg', '__pycache__']

# %%
# λήψη πληροφοριών για ένα αρχείο
print(os.stat('os.ipynb'))
from datetime import datetime
print(datetime.fromtimestamp(os.stat('os.ipynb').st_mtime))
# Out:
# os.stat_result(st_mode=33206, st_ino=1407374884946797, st_dev=7073154, st_nlink=1, st_uid=0, st_gid=0, st_size=1616, st_atime=1647352327, st_mtime=1614503455, st_ctime=1613688567)
# 2021-02-28 11:10:55.267291

# %%
# διάσχιση δένδρου καταλόγων
for dirpath, dirnames, filenames in os.walk("."):
    print("Current path:", dirpath)
    print("Directories:", dirnames)
    print("Files:", filenames)
    print("#" * 40)
# Out:
# Current path: ../
# Directories: ['concurrency', 'gui', 'interactive', 'lexer_parser', 'multiprocessing', 'notebooks', 'scraping', 'testing0', 'testing1', 'testing2', 'testing3', '__pycache__']
# Files: ['.pre-commit-config.yaml', 'closure1.py', 'closure2.py', 'closure3.py', 'closure4.py', 'code.md', 'defensive1.py', 'defensive2.py', 'defensive3.py', 'defensive4.py', 'fibo_heartrate.py', 'first_class_function1.py', 'first_class_function2.py', 'first_class_function3.py', 'first_class_function4.py', 'first_class_function5.py', 'generators_are_lazy.py', 'index.md', 'input1.py', 'loguru1.py', 'loguru2.py', 'my_module.py', 'os_walk.py', 'passwd.py', 'pass_by_assignment.py', 'paths_filenames.py', 'python01.py', 'python02.py', 'python03.py', 'python04a.py', 'python04b.py', 'python04c.py', 'python04d.py', 'python05.py', 'python06a.py', 'python06b.py', 'python07a.py', 'python07b.py', 'python08.py', 'python09.py', 'ranges_are_lazy.py', 'scope1a.py', 'scope1b.py', 'scope1c.py', 'scope2a.py', 'scope2b.py', 'simple_lambda.py', 'sort_with_lambda.py', 'temp.py', 'turtle1.py', 'use_of_my_module.py']
# ########################################
# Current path: ../concurrency
# Directories: ['__pycache__']
# Files: ['fib.py', 'index.md', 'server-1.py', 'server-2.py']
# ########################################
# Current path: ../concurrency\__pycache__
# Directories: []
# Files: ['fib.cpython-38.pyc']
# ########################################
# Current path: ../gui
# Directories: ['pyqt_todo', 'tkinter_canvas', 'tkinter_todo', 'wxpython_todo']
# Files: ['index.md']
# ########################################
# Current path: ../gui\pyqt_todo
# Directories: []
# Files: ['main.py', 'todolist.py', 'todolist.txt']
# ########################################
# Current path: ../gui\tkinter_canvas
# Directories: []
# Files: ['canvas_shapes.py']
# ########################################
# Current path: ../gui\tkinter_todo
# Directories: []
# Files: ['tkinter_canvas.png', 'tkinter_todo.png', 'todolist.py']
# ########################################
# Current path: ../gui\wxpython_todo
# Directories: ['.vscode']
# Files: ['01_hello.py', '02_hello.py', '03_click.py', '04_messagebox.py', 'index.md', 'todolist.py', 'wxpython_todo.png']
# ########################################
# Current path: ../gui\wxpython_todo\.vscode
# Directories: []
# Files: ['settings.json']
# ########################################
# Current path: ../interactive
# Directories: []
# Files: ['index.md', 'interactive01.py']
# ########################################
# Current path: ../lexer_parser
# Directories: ['__pycache__']
# Files: ['index.md', 'Lexer.py', 'LexerTest1.py', 'LexerTest2.py', 'Parser.py', 'Token.py', 'TokenTypes.py']
# ########################################
# Current path: ../lexer_parser\__pycache__
# Directories: []
# Files: ['Lexer.cpython-38.pyc', 'Token.cpython-38.pyc', 'TokenTypes.cpython-38.pyc']
# ########################################
# Current path: ../multiprocessing
# Directories: []
# Files: ['example01.py', 'example02.py', 'example03.py', 'example04.py', 'example05.py', 'index.md']
# ########################################
# Current path: ../notebooks
# Directories: ['.ipynb_checkpoints', '__pycache__']
# Files: ['01-intro.ipynb', '02-strings.ipynb', '03-lists-tuples-dictionaries-sets.ipynb', '04-conditionals.ipynb', '05-loops.ipynb', '06-comprehensions.ipynb', '07-exceptions.ipynb', '08-files.ipynb', '09-functions.ipynb', '10-lambdas.ipynb', '11-classes.ipynb', '12-logging.ipynb', '13-testing.ipynb', '14-csv.ipynb', '15-excel.ipynb', '16-xml.ipynb', '17-json.ipynb', '18-yaml.ipynb', '19-pickle.ipynb', '20-datetime.ipynb', '21-random.ipynb', '22-regular_expressions.ipynb', '23-generators.ipynb', '24-iterators.ipynb', '25-itertools.ipynb', '26-enums.ipynb', '27-urllib.ipynb', '28-requests.ipynb', '29-bs4.ipynb', '30-collections.ipynb', '31-PLY.ipynb', '32-alias.ipynb', '33-abstract_syntax_trees.ipynb', '34-operator_overloading.ipynb', 'APIs.ipynb', 'attrs.ipynb', 'birthday_paradox.pkl', 'code_analysis.ipynb', 'configparser.ipynb', 'convert.bat', 'coroutines.ipynb', 'data.pkl', 'decorators.ipynb', 'dituoi.pkl', 'easter_eggs.ipynb', 'functools.ipynb', 'LEGB.ipynb', 'mocking.ipynb', 'numpy.ipynb', 'os.ipynb', 'pandas.ipynb', 'parser.out', 'parsetab.py', 'partial_function_example1.py', 'partial_function_example2.py', 'print_debugging.ipynb', 'profiling.ipynb', 'pylint.ipynb', 'sample.log', 'seaborn.ipynb', 'sols.ipynb', 'sols7_1.ipynb', 'sols7_2a.ipynb', 'sols7_2a_alt.ipynb', 'sols7_2b.ipynb', 'sols7_2b_alt.ipynb', 'sqlite.ipynb', 'temp.ipynb', 'test.txt', 'threads.ipynb', 'wiki.jpg']
# ########################################
# Current path: ../notebooks\.ipynb_checkpoints
# Directories: []
# Files: ['01-intro-checkpoint.ipynb', '02-strings-checkpoint.ipynb', '03-lists-tuples-dictionaries-sets-checkpoint.ipynb', '04-conditionals-checkpoint.ipynb', '05-loops-checkpoint.ipynb', '06-comprehensions-checkpoint.ipynb', '07-exceptions-checkpoint.ipynb', '08-files-checkpoint.ipynb', '09-functions-checkpoint.ipynb', '10-lambdas-checkpoint.ipynb', '11-classes-checkpoint.ipynb', '12-logging-checkpoint.ipynb', '13-testing-checkpoint.ipynb', 'temp-checkpoint.ipynb', 'threads-checkpoint.ipynb']
# ########################################
# Current path: ../notebooks\__pycache__
# Directories: []
# Files: ['parsetab.cpython-38.pyc']
# ########################################
# Current path: ../scraping
# Directories: []
# Files: ['dit.py']
# ########################################
# Current path: ../testing0
# Directories: []
# Files: ['faculty.py']
# ########################################
# Current path: ../testing1
# Directories: ['.idea', 'venv']
# Files: ['index.md', 'set1.py', 'set1sol.py']
# ########################################
# Current path: ../testing1\.idea
# Directories: ['inspectionProfiles']
# Files: ['.gitignore', 'lab01.iml', 'misc.xml', 'modules.xml', 'vcs.xml', 'workspace.xml']
# ########################################
# Current path: ../testing1\.idea\inspectionProfiles
# Directories: []
# Files: ['profiles_settings.xml']
# ########################################
# Current path: ../testing1\venv
# Directories: ['Include', 'Lib', 'Scripts']
# Files: ['pyvenv.cfg']
# ########################################
# Current path: ../testing1\venv\Include
# Directories: []
# Files: []
# ########################################
# Current path: ../testing1\venv\Lib
# Directories: ['site-packages']
# Files: []
# ########################################
# Current path: ../testing1\venv\Lib\site-packages
# Directories: ['pip', 'pip-21.0.1.dist-info', 'pkg_resources', 'setuptools', 'setuptools-53.0.0.dist-info', '_distutils_hack']
# Files: ['distutils-precedence.pth']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip
# Directories: ['_internal', '_vendor', '__pycache__']
# Files: ['__init__.py', '__main__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal
# Directories: ['cli', 'commands', 'distributions', 'index', 'models', 'network', 'operations', 'req', 'resolution', 'utils', 'vcs', '__pycache__']
# Files: ['build_env.py', 'cache.py', 'configuration.py', 'exceptions.py', 'locations.py', 'main.py', 'pyproject.py', 'self_outdated_check.py', 'wheel_builder.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\cli
# Directories: ['__pycache__']
# Files: ['autocompletion.py', 'base_command.py', 'cmdoptions.py', 'command_context.py', 'main.py', 'main_parser.py', 'parser.py', 'progress_bars.py', 'req_command.py', 'spinners.py', 'status_codes.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\cli\__pycache__
# Directories: []
# Files: ['autocompletion.cpython-38.pyc', 'base_command.cpython-38.pyc', 'cmdoptions.cpython-38.pyc', 'command_context.cpython-38.pyc', 'main.cpython-38.pyc', 'main_parser.cpython-38.pyc', 'parser.cpython-38.pyc', 'progress_bars.cpython-38.pyc', 'req_command.cpython-38.pyc', 'spinners.cpython-38.pyc', 'status_codes.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\commands
# Directories: ['__pycache__']
# Files: ['cache.py', 'check.py', 'completion.py', 'configuration.py', 'debug.py', 'download.py', 'freeze.py', 'hash.py', 'help.py', 'install.py', 'list.py', 'search.py', 'show.py', 'uninstall.py', 'wheel.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\commands\__pycache__
# Directories: []
# Files: ['cache.cpython-38.pyc', 'check.cpython-38.pyc', 'completion.cpython-38.pyc', 'configuration.cpython-38.pyc', 'debug.cpython-38.pyc', 'download.cpython-38.pyc', 'freeze.cpython-38.pyc', 'hash.cpython-38.pyc', 'help.cpython-38.pyc', 'install.cpython-38.pyc', 'list.cpython-38.pyc', 'search.cpython-38.pyc', 'show.cpython-38.pyc', 'uninstall.cpython-38.pyc', 'wheel.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\distributions
# Directories: ['__pycache__']
# Files: ['base.py', 'installed.py', 'sdist.py', 'wheel.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\distributions\__pycache__
# Directories: []
# Files: ['base.cpython-38.pyc', 'installed.cpython-38.pyc', 'sdist.cpython-38.pyc', 'wheel.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\index
# Directories: ['__pycache__']
# Files: ['collector.py', 'package_finder.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\index\__pycache__
# Directories: []
# Files: ['collector.cpython-38.pyc', 'package_finder.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\models
# Directories: ['__pycache__']
# Files: ['candidate.py', 'direct_url.py', 'format_control.py', 'index.py', 'link.py', 'scheme.py', 'search_scope.py', 'selection_prefs.py', 'target_python.py', 'wheel.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\models\__pycache__
# Directories: []
# Files: ['candidate.cpython-38.pyc', 'direct_url.cpython-38.pyc', 'format_control.cpython-38.pyc', 'index.cpython-38.pyc', 'link.cpython-38.pyc', 'scheme.cpython-38.pyc', 'search_scope.cpython-38.pyc', 'selection_prefs.cpython-38.pyc', 'target_python.cpython-38.pyc', 'wheel.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\network
# Directories: ['__pycache__']
# Files: ['auth.py', 'cache.py', 'download.py', 'lazy_wheel.py', 'session.py', 'utils.py', 'xmlrpc.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\network\__pycache__
# Directories: []
# Files: ['auth.cpython-38.pyc', 'cache.cpython-38.pyc', 'download.cpython-38.pyc', 'lazy_wheel.cpython-38.pyc', 'session.cpython-38.pyc', 'utils.cpython-38.pyc', 'xmlrpc.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\operations
# Directories: ['build', 'install', '__pycache__']
# Files: ['check.py', 'freeze.py', 'prepare.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\operations\build
# Directories: ['__pycache__']
# Files: ['metadata.py', 'metadata_legacy.py', 'wheel.py', 'wheel_legacy.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\operations\build\__pycache__
# Directories: []
# Files: ['metadata.cpython-38.pyc', 'metadata_legacy.cpython-38.pyc', 'wheel.cpython-38.pyc', 'wheel_legacy.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\operations\install
# Directories: ['__pycache__']
# Files: ['editable_legacy.py', 'legacy.py', 'wheel.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\operations\install\__pycache__
# Directories: []
# Files: ['editable_legacy.cpython-38.pyc', 'legacy.cpython-38.pyc', 'wheel.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\operations\__pycache__
# Directories: []
# Files: ['check.cpython-38.pyc', 'freeze.cpython-38.pyc', 'prepare.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\req
# Directories: ['__pycache__']
# Files: ['constructors.py', 'req_file.py', 'req_install.py', 'req_set.py', 'req_tracker.py', 'req_uninstall.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\req\__pycache__
# Directories: []
# Files: ['constructors.cpython-38.pyc', 'req_file.cpython-38.pyc', 'req_install.cpython-38.pyc', 'req_set.cpython-38.pyc', 'req_tracker.cpython-38.pyc', 'req_uninstall.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\resolution
# Directories: ['legacy', 'resolvelib', '__pycache__']
# Files: ['base.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\resolution\legacy
# Directories: ['__pycache__']
# Files: ['resolver.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\resolution\legacy\__pycache__
# Directories: []
# Files: ['resolver.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\resolution\resolvelib
# Directories: ['__pycache__']
# Files: ['base.py', 'candidates.py', 'factory.py', 'found_candidates.py', 'provider.py', 'reporter.py', 'requirements.py', 'resolver.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\resolution\resolvelib\__pycache__
# Directories: []
# Files: ['base.cpython-38.pyc', 'candidates.cpython-38.pyc', 'factory.cpython-38.pyc', 'found_candidates.cpython-38.pyc', 'provider.cpython-38.pyc', 'reporter.cpython-38.pyc', 'requirements.cpython-38.pyc', 'resolver.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\resolution\__pycache__
# Directories: []
# Files: ['base.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\utils
# Directories: ['__pycache__']
# Files: ['appdirs.py', 'compat.py', 'compatibility_tags.py', 'datetime.py', 'deprecation.py', 'direct_url_helpers.py', 'distutils_args.py', 'encoding.py', 'entrypoints.py', 'filesystem.py', 'filetypes.py', 'glibc.py', 'hashes.py', 'inject_securetransport.py', 'logging.py', 'misc.py', 'models.py', 'packaging.py', 'parallel.py', 'pkg_resources.py', 'setuptools_build.py', 'subprocess.py', 'temp_dir.py', 'typing.py', 'unpacking.py', 'urls.py', 'virtualenv.py', 'wheel.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\utils\__pycache__
# Directories: []
# Files: ['appdirs.cpython-38.pyc', 'compat.cpython-38.pyc', 'compatibility_tags.cpython-38.pyc', 'datetime.cpython-38.pyc', 'deprecation.cpython-38.pyc', 'direct_url_helpers.cpython-38.pyc', 'distutils_args.cpython-38.pyc', 'encoding.cpython-38.pyc', 'entrypoints.cpython-38.pyc', 'filesystem.cpython-38.pyc', 'filetypes.cpython-38.pyc', 'glibc.cpython-38.pyc', 'hashes.cpython-38.pyc', 'inject_securetransport.cpython-38.pyc', 'logging.cpython-38.pyc', 'misc.cpython-38.pyc', 'models.cpython-38.pyc', 'packaging.cpython-38.pyc', 'parallel.cpython-38.pyc', 'pkg_resources.cpython-38.pyc', 'setuptools_build.cpython-38.pyc', 'subprocess.cpython-38.pyc', 'temp_dir.cpython-38.pyc', 'typing.cpython-38.pyc', 'unpacking.cpython-38.pyc', 'urls.cpython-38.pyc', 'virtualenv.cpython-38.pyc', 'wheel.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\vcs
# Directories: ['__pycache__']
# Files: ['bazaar.py', 'git.py', 'mercurial.py', 'subversion.py', 'versioncontrol.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\vcs\__pycache__
# Directories: []
# Files: ['bazaar.cpython-38.pyc', 'git.cpython-38.pyc', 'mercurial.cpython-38.pyc', 'subversion.cpython-38.pyc', 'versioncontrol.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_internal\__pycache__
# Directories: []
# Files: ['build_env.cpython-38.pyc', 'cache.cpython-38.pyc', 'configuration.cpython-38.pyc', 'exceptions.cpython-38.pyc', 'locations.cpython-38.pyc', 'main.cpython-38.pyc', 'pyproject.cpython-38.pyc', 'self_outdated_check.cpython-38.pyc', 'wheel_builder.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor
# Directories: ['cachecontrol', 'certifi', 'chardet', 'colorama', 'distlib', 'html5lib', 'idna', 'msgpack', 'packaging', 'pep517', 'pkg_resources', 'progress', 'requests', 'resolvelib', 'toml', 'urllib3', 'webencodings', '__pycache__']
# Files: ['appdirs.py', 'contextlib2.py', 'distro.py', 'pyparsing.py', 'retrying.py', 'six.py', 'vendor.txt', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\cachecontrol
# Directories: ['caches', '__pycache__']
# Files: ['adapter.py', 'cache.py', 'compat.py', 'controller.py', 'filewrapper.py', 'heuristics.py', 'serialize.py', 'wrapper.py', '_cmd.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\cachecontrol\caches
# Directories: ['__pycache__']
# Files: ['file_cache.py', 'redis_cache.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\cachecontrol\caches\__pycache__
# Directories: []
# Files: ['file_cache.cpython-38.pyc', 'redis_cache.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\cachecontrol\__pycache__
# Directories: []
# Files: ['adapter.cpython-38.pyc', 'cache.cpython-38.pyc', 'compat.cpython-38.pyc', 'controller.cpython-38.pyc', 'filewrapper.cpython-38.pyc', 'heuristics.cpython-38.pyc', 'serialize.cpython-38.pyc', 'wrapper.cpython-38.pyc', '_cmd.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\certifi
# Directories: ['__pycache__']
# Files: ['cacert.pem', 'core.py', '__init__.py', '__main__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\certifi\__pycache__
# Directories: []
# Files: ['core.cpython-38.pyc', '__init__.cpython-38.pyc', '__main__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\chardet
# Directories: ['cli', 'metadata', '__pycache__']
# Files: ['big5freq.py', 'big5prober.py', 'chardistribution.py', 'charsetgroupprober.py', 'charsetprober.py', 'codingstatemachine.py', 'compat.py', 'cp949prober.py', 'enums.py', 'escprober.py', 'escsm.py', 'eucjpprober.py', 'euckrfreq.py', 'euckrprober.py', 'euctwfreq.py', 'euctwprober.py', 'gb2312freq.py', 'gb2312prober.py', 'hebrewprober.py', 'jisfreq.py', 'jpcntx.py', 'langbulgarianmodel.py', 'langgreekmodel.py', 'langhebrewmodel.py', 'langhungarianmodel.py', 'langrussianmodel.py', 'langthaimodel.py', 'langturkishmodel.py', 'latin1prober.py', 'mbcharsetprober.py', 'mbcsgroupprober.py', 'mbcssm.py', 'sbcharsetprober.py', 'sbcsgroupprober.py', 'sjisprober.py', 'universaldetector.py', 'utf8prober.py', 'version.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\chardet\cli
# Directories: ['__pycache__']
# Files: ['chardetect.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\chardet\cli\__pycache__
# Directories: []
# Files: ['chardetect.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\chardet\metadata
# Directories: ['__pycache__']
# Files: ['languages.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\chardet\metadata\__pycache__
# Directories: []
# Files: ['languages.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\chardet\__pycache__
# Directories: []
# Files: ['big5freq.cpython-38.pyc', 'big5prober.cpython-38.pyc', 'chardistribution.cpython-38.pyc', 'charsetgroupprober.cpython-38.pyc', 'charsetprober.cpython-38.pyc', 'codingstatemachine.cpython-38.pyc', 'compat.cpython-38.pyc', 'cp949prober.cpython-38.pyc', 'enums.cpython-38.pyc', 'escprober.cpython-38.pyc', 'escsm.cpython-38.pyc', 'eucjpprober.cpython-38.pyc', 'euckrfreq.cpython-38.pyc', 'euckrprober.cpython-38.pyc', 'euctwfreq.cpython-38.pyc', 'euctwprober.cpython-38.pyc', 'gb2312freq.cpython-38.pyc', 'gb2312prober.cpython-38.pyc', 'hebrewprober.cpython-38.pyc', 'jisfreq.cpython-38.pyc', 'jpcntx.cpython-38.pyc', 'langbulgarianmodel.cpython-38.pyc', 'langgreekmodel.cpython-38.pyc', 'langhebrewmodel.cpython-38.pyc', 'langhungarianmodel.cpython-38.pyc', 'langrussianmodel.cpython-38.pyc', 'langthaimodel.cpython-38.pyc', 'langturkishmodel.cpython-38.pyc', 'latin1prober.cpython-38.pyc', 'mbcharsetprober.cpython-38.pyc', 'mbcsgroupprober.cpython-38.pyc', 'mbcssm.cpython-38.pyc', 'sbcharsetprober.cpython-38.pyc', 'sbcsgroupprober.cpython-38.pyc', 'sjisprober.cpython-38.pyc', 'universaldetector.cpython-38.pyc', 'utf8prober.cpython-38.pyc', 'version.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\colorama
# Directories: ['__pycache__']
# Files: ['ansi.py', 'ansitowin32.py', 'initialise.py', 'win32.py', 'winterm.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\colorama\__pycache__
# Directories: []
# Files: ['ansi.cpython-38.pyc', 'ansitowin32.cpython-38.pyc', 'initialise.cpython-38.pyc', 'win32.cpython-38.pyc', 'winterm.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\distlib
# Directories: ['_backport', '__pycache__']
# Files: ['compat.py', 'database.py', 'index.py', 'locators.py', 'manifest.py', 'markers.py', 'metadata.py', 'resources.py', 'scripts.py', 't32.exe', 't64.exe', 'util.py', 'version.py', 'w32.exe', 'w64.exe', 'wheel.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\distlib\_backport
# Directories: ['__pycache__']
# Files: ['misc.py', 'shutil.py', 'sysconfig.cfg', 'sysconfig.py', 'tarfile.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\distlib\_backport\__pycache__
# Directories: []
# Files: ['misc.cpython-38.pyc', 'shutil.cpython-38.pyc', 'sysconfig.cpython-38.pyc', 'tarfile.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\distlib\__pycache__
# Directories: []
# Files: ['compat.cpython-38.pyc', 'database.cpython-38.pyc', 'index.cpython-38.pyc', 'locators.cpython-38.pyc', 'manifest.cpython-38.pyc', 'markers.cpython-38.pyc', 'metadata.cpython-38.pyc', 'resources.cpython-38.pyc', 'scripts.cpython-38.pyc', 'util.cpython-38.pyc', 'version.cpython-38.pyc', 'wheel.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib
# Directories: ['filters', 'treeadapters', 'treebuilders', 'treewalkers', '_trie', '__pycache__']
# Files: ['constants.py', 'html5parser.py', 'serializer.py', '_ihatexml.py', '_inputstream.py', '_tokenizer.py', '_utils.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\filters
# Directories: ['__pycache__']
# Files: ['alphabeticalattributes.py', 'base.py', 'inject_meta_charset.py', 'lint.py', 'optionaltags.py', 'sanitizer.py', 'whitespace.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\filters\__pycache__
# Directories: []
# Files: ['alphabeticalattributes.cpython-38.pyc', 'base.cpython-38.pyc', 'inject_meta_charset.cpython-38.pyc', 'lint.cpython-38.pyc', 'optionaltags.cpython-38.pyc', 'sanitizer.cpython-38.pyc', 'whitespace.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\treeadapters
# Directories: ['__pycache__']
# Files: ['genshi.py', 'sax.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\treeadapters\__pycache__
# Directories: []
# Files: ['genshi.cpython-38.pyc', 'sax.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\treebuilders
# Directories: ['__pycache__']
# Files: ['base.py', 'dom.py', 'etree.py', 'etree_lxml.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\treebuilders\__pycache__
# Directories: []
# Files: ['base.cpython-38.pyc', 'dom.cpython-38.pyc', 'etree.cpython-38.pyc', 'etree_lxml.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\treewalkers
# Directories: ['__pycache__']
# Files: ['base.py', 'dom.py', 'etree.py', 'etree_lxml.py', 'genshi.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\treewalkers\__pycache__
# Directories: []
# Files: ['base.cpython-38.pyc', 'dom.cpython-38.pyc', 'etree.cpython-38.pyc', 'etree_lxml.cpython-38.pyc', 'genshi.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\_trie
# Directories: ['__pycache__']
# Files: ['py.py', '_base.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\_trie\__pycache__
# Directories: []
# Files: ['py.cpython-38.pyc', '_base.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\html5lib\__pycache__
# Directories: []
# Files: ['constants.cpython-38.pyc', 'html5parser.cpython-38.pyc', 'serializer.cpython-38.pyc', '_ihatexml.cpython-38.pyc', '_inputstream.cpython-38.pyc', '_tokenizer.cpython-38.pyc', '_utils.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\idna
# Directories: ['__pycache__']
# Files: ['codec.py', 'compat.py', 'core.py', 'idnadata.py', 'intranges.py', 'package_data.py', 'uts46data.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\idna\__pycache__
# Directories: []
# Files: ['codec.cpython-38.pyc', 'compat.cpython-38.pyc', 'core.cpython-38.pyc', 'idnadata.cpython-38.pyc', 'intranges.cpython-38.pyc', 'package_data.cpython-38.pyc', 'uts46data.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\msgpack
# Directories: ['__pycache__']
# Files: ['exceptions.py', 'ext.py', 'fallback.py', '_version.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\msgpack\__pycache__
# Directories: []
# Files: ['exceptions.cpython-38.pyc', 'ext.cpython-38.pyc', 'fallback.cpython-38.pyc', '_version.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\packaging
# Directories: ['__pycache__']
# Files: ['markers.py', 'requirements.py', 'specifiers.py', 'tags.py', 'utils.py', 'version.py', '_compat.py', '_structures.py', '_typing.py', '__about__.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\packaging\__pycache__
# Directories: []
# Files: ['markers.cpython-38.pyc', 'requirements.cpython-38.pyc', 'specifiers.cpython-38.pyc', 'tags.cpython-38.pyc', 'utils.cpython-38.pyc', 'version.cpython-38.pyc', '_compat.cpython-38.pyc', '_structures.cpython-38.pyc', '_typing.cpython-38.pyc', '__about__.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\pep517
# Directories: ['__pycache__']
# Files: ['build.py', 'check.py', 'colorlog.py', 'compat.py', 'dirtools.py', 'envbuild.py', 'meta.py', 'wrappers.py', '_in_process.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\pep517\__pycache__
# Directories: []
# Files: ['build.cpython-38.pyc', 'check.cpython-38.pyc', 'colorlog.cpython-38.pyc', 'compat.cpython-38.pyc', 'dirtools.cpython-38.pyc', 'envbuild.cpython-38.pyc', 'meta.cpython-38.pyc', 'wrappers.cpython-38.pyc', '_in_process.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\pkg_resources
# Directories: ['__pycache__']
# Files: ['py31compat.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\pkg_resources\__pycache__
# Directories: []
# Files: ['py31compat.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\progress
# Directories: ['__pycache__']
# Files: ['bar.py', 'counter.py', 'spinner.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\progress\__pycache__
# Directories: []
# Files: ['bar.cpython-38.pyc', 'counter.cpython-38.pyc', 'spinner.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\requests
# Directories: ['__pycache__']
# Files: ['adapters.py', 'api.py', 'auth.py', 'certs.py', 'compat.py', 'cookies.py', 'exceptions.py', 'help.py', 'hooks.py', 'models.py', 'packages.py', 'sessions.py', 'status_codes.py', 'structures.py', 'utils.py', '_internal_utils.py', '__init__.py', '__version__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\requests\__pycache__
# Directories: []
# Files: ['adapters.cpython-38.pyc', 'api.cpython-38.pyc', 'auth.cpython-38.pyc', 'certs.cpython-38.pyc', 'compat.cpython-38.pyc', 'cookies.cpython-38.pyc', 'exceptions.cpython-38.pyc', 'help.cpython-38.pyc', 'hooks.cpython-38.pyc', 'models.cpython-38.pyc', 'packages.cpython-38.pyc', 'sessions.cpython-38.pyc', 'status_codes.cpython-38.pyc', 'structures.cpython-38.pyc', 'utils.cpython-38.pyc', '_internal_utils.cpython-38.pyc', '__init__.cpython-38.pyc', '__version__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\resolvelib
# Directories: ['compat', '__pycache__']
# Files: ['providers.py', 'reporters.py', 'resolvers.py', 'structs.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\resolvelib\compat
# Directories: ['__pycache__']
# Files: ['collections_abc.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\resolvelib\compat\__pycache__
# Directories: []
# Files: ['collections_abc.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\resolvelib\__pycache__
# Directories: []
# Files: ['providers.cpython-38.pyc', 'reporters.cpython-38.pyc', 'resolvers.cpython-38.pyc', 'structs.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\toml
# Directories: ['__pycache__']
# Files: ['decoder.py', 'encoder.py', 'ordered.py', 'tz.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\toml\__pycache__
# Directories: []
# Files: ['decoder.cpython-38.pyc', 'encoder.cpython-38.pyc', 'ordered.cpython-38.pyc', 'tz.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3
# Directories: ['contrib', 'packages', 'util', '__pycache__']
# Files: ['connection.py', 'connectionpool.py', 'exceptions.py', 'fields.py', 'filepost.py', 'poolmanager.py', 'request.py', 'response.py', '_collections.py', '_version.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\contrib
# Directories: ['_securetransport', '__pycache__']
# Files: ['appengine.py', 'ntlmpool.py', 'pyopenssl.py', 'securetransport.py', 'socks.py', '_appengine_environ.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\contrib\_securetransport
# Directories: ['__pycache__']
# Files: ['bindings.py', 'low_level.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\contrib\_securetransport\__pycache__
# Directories: []
# Files: ['bindings.cpython-38.pyc', 'low_level.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\contrib\__pycache__
# Directories: []
# Files: ['appengine.cpython-38.pyc', 'ntlmpool.cpython-38.pyc', 'pyopenssl.cpython-38.pyc', 'securetransport.cpython-38.pyc', 'socks.cpython-38.pyc', '_appengine_environ.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\packages
# Directories: ['backports', 'ssl_match_hostname', '__pycache__']
# Files: ['six.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\packages\backports
# Directories: ['__pycache__']
# Files: ['makefile.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\packages\backports\__pycache__
# Directories: []
# Files: ['makefile.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\packages\ssl_match_hostname
# Directories: ['__pycache__']
# Files: ['_implementation.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\packages\ssl_match_hostname\__pycache__
# Directories: []
# Files: ['_implementation.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\packages\__pycache__
# Directories: []
# Files: ['six.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\util
# Directories: ['__pycache__']
# Files: ['connection.py', 'proxy.py', 'queue.py', 'request.py', 'response.py', 'retry.py', 'ssltransport.py', 'ssl_.py', 'timeout.py', 'url.py', 'wait.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\util\__pycache__
# Directories: []
# Files: ['connection.cpython-38.pyc', 'proxy.cpython-38.pyc', 'queue.cpython-38.pyc', 'request.cpython-38.pyc', 'response.cpython-38.pyc', 'retry.cpython-38.pyc', 'ssltransport.cpython-38.pyc', 'ssl_.cpython-38.pyc', 'timeout.cpython-38.pyc', 'url.cpython-38.pyc', 'wait.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\urllib3\__pycache__
# Directories: []
# Files: ['connection.cpython-38.pyc', 'connectionpool.cpython-38.pyc', 'exceptions.cpython-38.pyc', 'fields.cpython-38.pyc', 'filepost.cpython-38.pyc', 'poolmanager.cpython-38.pyc', 'request.cpython-38.pyc', 'response.cpython-38.pyc', '_collections.cpython-38.pyc', '_version.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\webencodings
# Directories: ['__pycache__']
# Files: ['labels.py', 'mklabels.py', 'tests.py', 'x_user_defined.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\webencodings\__pycache__
# Directories: []
# Files: ['labels.cpython-38.pyc', 'mklabels.cpython-38.pyc', 'tests.cpython-38.pyc', 'x_user_defined.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\_vendor\__pycache__
# Directories: []
# Files: ['appdirs.cpython-38.pyc', 'contextlib2.cpython-38.pyc', 'distro.cpython-38.pyc', 'pyparsing.cpython-38.pyc', 'retrying.cpython-38.pyc', 'six.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip\__pycache__
# Directories: []
# Files: ['__init__.cpython-38.pyc', '__main__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pip-21.0.1.dist-info
# Directories: []
# Files: ['entry_points.txt', 'INSTALLER', 'LICENSE.txt', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources
# Directories: ['extern', 'tests', '_vendor', '__pycache__']
# Files: ['__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\extern
# Directories: ['__pycache__']
# Files: ['__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\extern\__pycache__
# Directories: []
# Files: ['__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\tests
# Directories: ['data']
# Files: []
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\tests\data
# Directories: ['my-test-package-source']
# Files: []
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\tests\data\my-test-package-source
# Directories: ['__pycache__']
# Files: ['setup.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\tests\data\my-test-package-source\__pycache__
# Directories: []
# Files: ['setup.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\_vendor
# Directories: ['packaging', '__pycache__']
# Files: ['appdirs.py', 'pyparsing.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\_vendor\packaging
# Directories: ['__pycache__']
# Files: ['markers.py', 'requirements.py', 'specifiers.py', 'tags.py', 'utils.py', 'version.py', '_compat.py', '_structures.py', '_typing.py', '__about__.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\_vendor\packaging\__pycache__
# Directories: []
# Files: ['markers.cpython-38.pyc', 'requirements.cpython-38.pyc', 'specifiers.cpython-38.pyc', 'tags.cpython-38.pyc', 'utils.cpython-38.pyc', 'version.cpython-38.pyc', '_compat.cpython-38.pyc', '_structures.cpython-38.pyc', '_typing.cpython-38.pyc', '__about__.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\_vendor\__pycache__
# Directories: []
# Files: ['appdirs.cpython-38.pyc', 'pyparsing.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\pkg_resources\__pycache__
# Directories: []
# Files: ['__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools
# Directories: ['command', 'extern', '_distutils', '_vendor', '__pycache__']
# Files: ['archive_util.py', 'build_meta.py', 'cli-32.exe', 'cli-64.exe', 'cli.exe', 'config.py', 'depends.py', 'dep_util.py', 'dist.py', 'errors.py', 'extension.py', 'glob.py', 'gui-32.exe', 'gui-64.exe', 'gui.exe', 'installer.py', 'launch.py', 'lib2to3_ex.py', 'monkey.py', 'msvc.py', 'namespaces.py', 'package_index.py', 'py34compat.py', 'sandbox.py', 'script (dev).tmpl', 'script.tmpl', 'ssl_support.py', 'unicode_utils.py', 'version.py', 'wheel.py', 'windows_support.py', '_deprecation_warning.py', '_imp.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\command
# Directories: ['__pycache__']
# Files: ['alias.py', 'bdist_egg.py', 'bdist_rpm.py', 'bdist_wininst.py', 'build_clib.py', 'build_ext.py', 'build_py.py', 'develop.py', 'dist_info.py', 'easy_install.py', 'egg_info.py', 'install.py', 'install_egg_info.py', 'install_lib.py', 'install_scripts.py', 'launcher manifest.xml', 'py36compat.py', 'register.py', 'rotate.py', 'saveopts.py', 'sdist.py', 'setopt.py', 'test.py', 'upload.py', 'upload_docs.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\command\__pycache__
# Directories: []
# Files: ['alias.cpython-38.pyc', 'bdist_egg.cpython-38.pyc', 'bdist_rpm.cpython-38.pyc', 'bdist_wininst.cpython-38.pyc', 'build_clib.cpython-38.pyc', 'build_ext.cpython-38.pyc', 'build_py.cpython-38.pyc', 'develop.cpython-38.pyc', 'dist_info.cpython-38.pyc', 'easy_install.cpython-38.pyc', 'egg_info.cpython-38.pyc', 'install.cpython-38.pyc', 'install_egg_info.cpython-38.pyc', 'install_lib.cpython-38.pyc', 'install_scripts.cpython-38.pyc', 'py36compat.cpython-38.pyc', 'register.cpython-38.pyc', 'rotate.cpython-38.pyc', 'saveopts.cpython-38.pyc', 'sdist.cpython-38.pyc', 'setopt.cpython-38.pyc', 'test.cpython-38.pyc', 'upload.cpython-38.pyc', 'upload_docs.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\extern
# Directories: ['__pycache__']
# Files: ['__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\extern\__pycache__
# Directories: []
# Files: ['__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_distutils
# Directories: ['command', '__pycache__']
# Files: ['archive_util.py', 'bcppcompiler.py', 'ccompiler.py', 'cmd.py', 'config.py', 'core.py', 'cygwinccompiler.py', 'debug.py', 'dep_util.py', 'dir_util.py', 'dist.py', 'errors.py', 'extension.py', 'fancy_getopt.py', 'filelist.py', 'file_util.py', 'log.py', 'msvc9compiler.py', 'msvccompiler.py', 'py35compat.py', 'py38compat.py', 'spawn.py', 'sysconfig.py', 'text_file.py', 'unixccompiler.py', 'util.py', 'version.py', 'versionpredicate.py', '_msvccompiler.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_distutils\command
# Directories: ['__pycache__']
# Files: ['bdist.py', 'bdist_dumb.py', 'bdist_msi.py', 'bdist_rpm.py', 'bdist_wininst.py', 'build.py', 'build_clib.py', 'build_ext.py', 'build_py.py', 'build_scripts.py', 'check.py', 'clean.py', 'config.py', 'install.py', 'install_data.py', 'install_egg_info.py', 'install_headers.py', 'install_lib.py', 'install_scripts.py', 'py37compat.py', 'register.py', 'sdist.py', 'upload.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_distutils\command\__pycache__
# Directories: []
# Files: ['bdist.cpython-38.pyc', 'bdist_dumb.cpython-38.pyc', 'bdist_msi.cpython-38.pyc', 'bdist_rpm.cpython-38.pyc', 'bdist_wininst.cpython-38.pyc', 'build.cpython-38.pyc', 'build_clib.cpython-38.pyc', 'build_ext.cpython-38.pyc', 'build_py.cpython-38.pyc', 'build_scripts.cpython-38.pyc', 'check.cpython-38.pyc', 'clean.cpython-38.pyc', 'config.cpython-38.pyc', 'install.cpython-38.pyc', 'install_data.cpython-38.pyc', 'install_egg_info.cpython-38.pyc', 'install_headers.cpython-38.pyc', 'install_lib.cpython-38.pyc', 'install_scripts.cpython-38.pyc', 'py37compat.cpython-38.pyc', 'register.cpython-38.pyc', 'sdist.cpython-38.pyc', 'upload.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_distutils\__pycache__
# Directories: []
# Files: ['archive_util.cpython-38.pyc', 'bcppcompiler.cpython-38.pyc', 'ccompiler.cpython-38.pyc', 'cmd.cpython-38.pyc', 'config.cpython-38.pyc', 'core.cpython-38.pyc', 'cygwinccompiler.cpython-38.pyc', 'debug.cpython-38.pyc', 'dep_util.cpython-38.pyc', 'dir_util.cpython-38.pyc', 'dist.cpython-38.pyc', 'errors.cpython-38.pyc', 'extension.cpython-38.pyc', 'fancy_getopt.cpython-38.pyc', 'filelist.cpython-38.pyc', 'file_util.cpython-38.pyc', 'log.cpython-38.pyc', 'msvc9compiler.cpython-38.pyc', 'msvccompiler.cpython-38.pyc', 'py35compat.cpython-38.pyc', 'py38compat.cpython-38.pyc', 'spawn.cpython-38.pyc', 'sysconfig.cpython-38.pyc', 'text_file.cpython-38.pyc', 'unixccompiler.cpython-38.pyc', 'util.cpython-38.pyc', 'version.cpython-38.pyc', 'versionpredicate.cpython-38.pyc', '_msvccompiler.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_vendor
# Directories: ['packaging', '__pycache__']
# Files: ['ordered_set.py', 'pyparsing.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_vendor\packaging
# Directories: ['__pycache__']
# Files: ['markers.py', 'requirements.py', 'specifiers.py', 'tags.py', 'utils.py', 'version.py', '_compat.py', '_structures.py', '_typing.py', '__about__.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_vendor\packaging\__pycache__
# Directories: []
# Files: ['markers.cpython-38.pyc', 'requirements.cpython-38.pyc', 'specifiers.cpython-38.pyc', 'tags.cpython-38.pyc', 'utils.cpython-38.pyc', 'version.cpython-38.pyc', '_compat.cpython-38.pyc', '_structures.cpython-38.pyc', '_typing.cpython-38.pyc', '__about__.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\_vendor\__pycache__
# Directories: []
# Files: ['ordered_set.cpython-38.pyc', 'pyparsing.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools\__pycache__
# Directories: []
# Files: ['archive_util.cpython-38.pyc', 'build_meta.cpython-38.pyc', 'config.cpython-38.pyc', 'depends.cpython-38.pyc', 'dep_util.cpython-38.pyc', 'dist.cpython-38.pyc', 'errors.cpython-38.pyc', 'extension.cpython-38.pyc', 'glob.cpython-38.pyc', 'installer.cpython-38.pyc', 'launch.cpython-38.pyc', 'lib2to3_ex.cpython-38.pyc', 'monkey.cpython-38.pyc', 'msvc.cpython-38.pyc', 'namespaces.cpython-38.pyc', 'package_index.cpython-38.pyc', 'py34compat.cpython-38.pyc', 'sandbox.cpython-38.pyc', 'ssl_support.cpython-38.pyc', 'unicode_utils.cpython-38.pyc', 'version.cpython-38.pyc', 'wheel.cpython-38.pyc', 'windows_support.cpython-38.pyc', '_deprecation_warning.cpython-38.pyc', '_imp.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\setuptools-53.0.0.dist-info
# Directories: []
# Files: ['dependency_links.txt', 'entry_points.txt', 'INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'top_level.txt', 'WHEEL']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\_distutils_hack
# Directories: ['__pycache__']
# Files: ['override.py', '__init__.py']
# ########################################
# Current path: ../testing1\venv\Lib\site-packages\_distutils_hack\__pycache__
# Directories: []
# Files: ['override.cpython-38.pyc', '__init__.cpython-38.pyc']
# ########################################
# Current path: ../testing1\venv\Scripts
# Directories: []
# Files: ['activate', 'activate.bat', 'Activate.ps1', 'deactivate.bat', 'pip.exe', 'pip3.8.exe', 'pip3.exe', 'python.exe', 'pythonw.exe']
# ########################################
# Current path: ../testing2
# Directories: ['__pycache__']
# Files: ['calc.py', 'index.md', 'test_calc.py']
# ########################################
# Current path: ../testing2\__pycache__
# Directories: []
# Files: ['calc.cpython-38.pyc']
# ########################################
# Current path: ../testing3
# Directories: ['__pycache__']
# Files: ['employee.py', 'index.md', 'test_employee.py']
# ########################################
# Current path: ../testing3\__pycache__
# Directories: []
# Files: ['employee.cpython-38.pyc']
# ########################################
# Current path: ../__pycache__
# Directories: []
# Files: ['my_module.cpython-310.pyc', 'python01.cpython-38.pyc', 'python02.cpython-38.pyc']
# ########################################

# %%
# μεταβλητές περιβάλλοντος
os.getenv('PATH');

# %%
# λήψη  καταλόγου, ονόματος αρχείου και επέκτασης αρχείου στο οποίο αντιστοιχεί μια διαδρομή προς ένα αρχείο
print(os.path.basename('/home/sub/test.txt')) 
print(os.path.split('/home/sub/test.txt'))
print(os.path.splitext('/home/sub/test.txt'))
print(os.path.exists('/home/sub/test.txt')) # έλεγχος αν το αρχείο υπάρχει
# Out:
# test.txt
# ('/home/sub', 'test.txt')
# ('/home/sub/test', '.txt')
# False

# %%
# έλεγχος αν μια διαδρομή οδηγεί σε αρχείο ή σε κατάλογο
print(os.path.isdir('os.ipynb'))
print(os.path.isfile('os.ipynb'))
# Out:
# False
# True
